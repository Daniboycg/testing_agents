# %%
from abc import ABC, abstractmethod
from datetime import datetime
import requests
import json
from pydifact.segmentcollection import Interchange
from pydifact.segments import Segment
from pydifact.control.characters import Characters
from datetime import datetime
from enum import Enum
from typing import List, Literal, Optional, Union

import fitz
import instructor
from openai import AsyncOpenAI, OpenAI
from pydantic import BaseModel, Field
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
client = instructor.patch(OpenAI(), mode=instructor.Mode.JSON)

# %%
# Load the structured examples from the JSON file
with open('./data/structured_examples_cleaned.json', 'r') as file:
    structured_examples = json.load(file)

print(f"Loaded {len(structured_examples)} structured examples.")
# Out:
# Loaded 5 structured examples.

# %%
def parse_edifact_message(edifact_message):
    try:
        interchange = Interchange.from_str(edifact_message)
        interchange.validate()
        
        message_dict = {}

        # Iterate through messages and segments, populating the dictionary
        for message in interchange.get_messages():
            message_header = message.get_header_segment()

            message_dict[message_header.tag] = message_header.elements
            for segment in message.segments:
                tag = segment.tag
                if tag not in message_dict:
                    message_dict[tag] = []
                message_dict[tag].extend(segment.elements)

            message_footer = message.get_footer_segment()

            if message_footer.tag not in message_dict:
                message_dict[message_footer.tag] = []
            message_dict[message_footer.tag].extend(message_footer.elements)

        return message_dict
    except Exception as e:
        return f"Interchange validation error: {e}"

# %%
print(structured_examples[0])
# Out:
# {'edifact_input': "UNB+IATA:1+W1+ON+240703:1456+0001'\nUNH+1+DCQSMF:03:1:IA'\nLOR+W1:INK'\nFDQ+IN+3202+240703+BCN+MAD++IN+3201+2407030900+2407031100+INK+BCN'\nUNT+4+1'\nUNZ+1+0001'\n", 'ink_api_url': 'https://api-staging.inkcloud.io/api/1.8/seat_plan/get_seat_plan?station_iata=BCN&flight_number=IN3202&departure_date=2024-07-03', 'api_response': {'carrier_name': 'Ink Aviation', 'carrier_code': 'IN', 'airplane_model': 'A320', 'cabin_configuration': 'Y180', 'seat_plan_class': [{'name': 'Economy', 'seat_plan_row': [{'row': 1, 'seat_plan_position': [{'seat_number': '1A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '1D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 2, 'seat_plan_position': [{'seat_number': '2A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '2D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 3, 'seat_plan_position': [{'seat_number': '3A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '3D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 4, 'seat_plan_position': [{'seat_number': '4A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '4D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 5, 'seat_plan_position': [{'seat_number': '5A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '5D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 6, 'seat_plan_position': [{'seat_number': '6A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '6D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 7, 'seat_plan_position': [{'seat_number': '7A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '7D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 8, 'seat_plan_position': [{'seat_number': '8A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '8D', 'exit_seat': False, 'type': 'seat'}, {'s ...

# %%
parse_edifact_message("UNB+IATA:1+W1+ON+240703:1456+0001'\nUNH+1+DCQSMF:03:1:IA'\nLOR+W1:INK'\nFDQ+IN+3202+240703+BCN+MAD++IN+3201+2407030900+2407031100+INK+BCN'\nUNT+4+1'\nUNZ+1+0001'\n")
# Out:
# {'UNH': ['1', ['DCQSMF', '03', '1', 'IA']],
#  'LOR': [['W1', 'INK']],
#  'FDQ': ['IN',
#   '3202',
#   '240703',
#   'BCN',
#   'MAD',
#   '',
#   'IN',
#   '3201',
#   '2407030900',
#   '2407031100',
#   'INK',
#   'BCN'],
#  'UNT': ['4', '1']}

# %%
test_example = structured_examples[0]
for key in test_example.keys():
    print(key)
# Out:
# edifact_input
# ink_api_url
# api_response
# edifact_output

# %%
class EdifactEncoder(BaseModel):
    encoding_function: str = Field(description="Python code for the encoder function")

# %%
SYSTEM_PROMPT = f""" # Purpose
You are an expert programmer specializing in python and edifact

# Instructions
- Based On:
    - An input edifact message
    - API Response
    - Proper Output Edifact Response
- Write code to format the edifact response based on inputs

# Rules
- The code must be adaptive and work for ALL possible inputs
- Only hardcode values that 100% NEED to be hardcoded
    - Always pass values where applicable

# Input
- Input Edifact Message
- API Response
- Proper Output Edifact Response

# Output
- Encoding Function
"""

# %%
def format_examples(examples):
    out_string = "# Examples\n"
    for i, example in enumerate(examples):
        out_string += f"## Example {i}\n"
        out_string += f"### Input Edifact Message:\n{example['edifact_input']}\n"
        out_string += f"### API Response:\n{example['api_response']}\n"
        out_string += f"### Proper Output Edifact Response:\n{example['edifact_output']}\n"
    return out_string

# %%
print(format_examples(structured_examples))
# Out:
# # Examples
# ## Example 0
# ### Input Edifact Message:
# UNB+IATA:1+W1+ON+240703:1456+0001'
# UNH+1+DCQSMF:03:1:IA'
# LOR+W1:INK'
# FDQ+IN+3202+240703+BCN+MAD++IN+3201+2407030900+2407031100+INK+BCN'
# UNT+4+1'
# UNZ+1+0001'
#
# ### API Response:
# {'carrier_name': 'Ink Aviation', 'carrier_code': 'IN', 'airplane_model': 'A320', 'cabin_configuration': 'Y180', 'seat_plan_class': [{'name': 'Economy', 'seat_plan_row': [{'row': 1, 'seat_plan_position': [{'seat_number': '1A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '1D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 2, 'seat_plan_position': [{'seat_number': '2A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '2D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 3, 'seat_plan_position': [{'seat_number': '3A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '3D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 4, 'seat_plan_position': [{'seat_number': '4A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '4D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 5, 'seat_plan_position': [{'seat_number': '5A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '5D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 6, 'seat_plan_position': [{'seat_number': '6A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '6D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 7, 'seat_plan_position': [{'seat_number': '7A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '7D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 8, 'seat_plan_position': [{'seat_number': '8A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '8D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 9, 'seat_plan_position': [{'seat_number': '9A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '9B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '9C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai ...
# ### Proper Output Edifact Response:
# UNB+IATA:1+ON+W1+240703:1456+0001'
# UNH+1+DCRSMF:03:1:IA'
# FDR+IN+3202+2407031300+BCN+MAD+2407031400'
# RAD+S+O'
# EQD+Y:180+++++320'
# CBD+Y+1:30+++++A:W+B:N+C:A+D:A+E:N+F:W'
# ROD+1++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+2++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+3++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+4++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+5++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+6++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+7++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+8++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+9++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+10++A:F:N:W:E+B:F:N:E+C:F:N:A:E+D:F:N:A:E+E:F:N:E+F:F:N:W:E'
# ROD+11++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+12++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+13++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+14++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+15++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+16++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+17++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+18++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+19++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+20++A:F:N:W:E+B:F:N:E+C:F:N:A:E+D:F:N:A:E+E:F:N:E+F:F:N:W:E'
# ROD+21++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+22++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+23++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+24++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+25++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+26++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+27++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+28++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+29++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# ROD+30++A:F:N:W+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W'
# UNT+36+1'
# UNZ+1+0001'
# ## Example 1
# ### Input Edifact Message:
# UNB+IATA:1+W1+ON+240703:1601+0001'
# UNH+1+DCQSMF:03:1:IA'
# LOR+W1:CUN'
# FDQ+DM+1791+240704+SDQ+CUN++DM+1792+2407061052+2407061447+CUN+SDQ'
# UNT+4+1'
# UNZ+1+0001'
#
# ### API Response:
# {'carrier_name': 'Arajet', 'carrier_code': 'DM', 'airplane_model': '737-8', 'cabin_configuration': 'REST 185 SEATS - FEB24', 'seat_plan_class': [{'name': 'Economy', 'seat_plan_row': [{'row': 1, 'seat_plan_position': [{'seat_number': '1A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '1D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 2, 'seat_plan_position': [{'seat_number': '2A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '2D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 3, 'seat_plan_position': [{'seat_number': '3A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '3D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 4, 'seat_plan_position': [{'seat_number': '4A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '4D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 5, 'seat_plan_position': [{'seat_number': '5A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '5D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 6, 'seat_plan_position': [{'seat_number': '6A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '6D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 7, 'seat_plan_position': [{'seat_number': '7A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '7D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 8, 'seat_plan_position': [{'seat_number': '8A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '8D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 9, 'seat_plan_position': [{'seat_number': '9A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '9B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '9C', 'exit_seat': False, 'type': 'seat'}, {'seat ...
# ### Proper Output Edifact Response:
# UNB+IATA:1+ON+W1+240703:1601+0001'
# UNH+1+DCRSMF:03:1:IA'
# FDR+DM+1791+2407040931+SDQ+CUN+2407041135'
# RAD+S+O'
# EQD+Y:192+++++7M8'
# CBD+Y+1:33+++++A:N+B:N+C:N+D:N+E:N+F:N'
# ROD+1++A:F:N:I+B:O:N+C:F:N:I+D:O:N:I+E:O:N+F:O:N:I'
# ROD+2++A:F:N:I+B:O:N+C:F:N:I+D:F:N:I+E:O:N+F:F:N:I'
# ROD+3++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+4++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+5++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+6++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+7++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+8++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+9++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+10++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+11++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+12++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+14++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+15++A:F:N:E+B:F:N:E+C:F:N:E+D:F:N:E+E:F:N:E+F:F:N:E'
# ROD+16++A:F:N:E+B:F:N:E+C:F:N:E+D:F:N:E+E:F:N:E+F:F:N:E'
# ROD+17++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+18++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+19++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+20++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+21++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+22++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+23++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+24++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+25++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+26++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+27++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+28++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+29++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+30++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+31++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+32++A:F:N:I+B:F:N:I+C:F:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# ROD+33++A:O:N:I+B:O:N:I+C:O:N:I+D:F:N:I+E:F:N:I+F:F:N:I'
# UNT+38+1'
# UNZ+1+0001'
# ## Example 2
# ### Input Edifact Message:
# UNB+IATA:1+W1+ON+240703:1616+0001'
# UNH+1+DCQSMF:03:1:IA'
# LOR+W1:JNB'
# FDQ+FA+293+240629+CPT+JNB++FA+113+2407061815+2407062030+JNB+CPT'
# UNT+4+1'
# UNZ+1+0001'
#
# ### API Response:
# {'carrier_name': 'FlySafair', 'carrier_code': 'FA', 'airplane_model': '737-800', 'cabin_configuration': 'Y189', 'seat_plan_class': [{'name': 'Economy', 'seat_plan_row': [{'row': 1, 'seat_plan_position': [{'seat_number': '1A', 'exit_seat': True, 'type': 'seat'}, {'seat_number': '1B', 'exit_seat': True, 'type': 'seat'}, {'seat_number': '1C', 'exit_seat': True, 'type': 'seat'}]}, {'row': 2, 'seat_plan_position': [{'seat_number': '2A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 3, 'seat_plan_position': [{'seat_number': '3A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 4, 'seat_plan_position': [{'seat_number': '4A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 5, 'seat_plan_position': [{'seat_number': '5A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 6, 'seat_plan_position': [{'seat_number': '6A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 7, 'seat_plan_position': [{'seat_number': '7A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 8, 'seat_plan_position': [{'seat_number': '8A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 9, 'seat_plan_position': [{'seat_number': '9A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '9B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '9C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '9D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '9E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '9F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 10, 'seat_plan_position': [{'seat_number': '10A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '10B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '10C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '10D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '10E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '10F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 11, 'seat_plan_position': [{'seat_number': '11A', 'exit_seat': False, 'type': 'seat'}, {'seat_n ...
# ### Proper Output Edifact Response:
# UNB+IATA:1+ON+W1+240703:1616+0001'
# UNH+1+DCRSMF:03:1:IA'
# FDR+FA+293+2406290700+CPT+JNB+2406290905'
# RAD+S+O'
# EQD+A:189+++++738'
# CBD+Y+1:33+++++A:W+B:N+C:A+D:A+E:N+F:W'
# ROD+1++A:O:N:W:E+B:O:N:E+C:O:N:A:E'
# ROD+2++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+3++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+4++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+5++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+6++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+7++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+8++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+9++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+10++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+11++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+12++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+14++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+15++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+16++A:F:N:W:E+B:F:N:E+C:F:N:A:E+D:F:N:A:E+E:F:N:E+F:F:N:W:E'
# ROD+17++A:F:N:W:E+B:F:N:E+C:F:N:A:E+D:F:N:A:E+E:F:N:E+F:F:N:W:E'
# ROD+18++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+19++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+20++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+21++A:O:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+22++A:F:N:W+B:O:N+C:O:N:A:I+D:O:N:A:I+E:F:N+F:F:N:W'
# ROD+23++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+24++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+25++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:O:N:W'
# ROD+26++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+27++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+28++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+29++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+30++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+31++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+32++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# ROD+33++A:F:N:W+B:F:N+C:F:N:A:I+D:F:N:A:I+E:F:N+F:F:N:W'
# UNT+38+1'
# UNZ+1+0001'
# ## Example 3
# ### Input Edifact Message:
# UNB+IATA:1+W1+ON+240703:1625+0001'
# UNH+1+DCQSMF:03:1:IA'
# LOR+W1:BOG'
# FDQ+P5+7025+240708+PUJ+BOG++P5+7024+2407051532+2407051916+BOG+PUJ'
# UNT+4+1'
# UNZ+1+0001'
#
# ### API Response:
# {'error': [{'error_code': '036', 'error_message': 'Flight not found'}]}
# ### Proper Output Edifact Response:
# UNB+IATA:1+ON+W1+240703:1625+0001'
# UNH+1+DCRSMF:03:1:IA'
# FDR+P5+7025+240708+PUJ+BOG'
# RAD+S+O'
# ERD+1:5'
# UNT+5+1'
# UNZ+1+0001'
# ## Example 4
# ### Input Edifact Message:
# UNB+IATA:1+W1+ON+240703:1634+0001'
# UNH+1+DCQSMF:03:1:IA'
# LOR+W1:BOG'
# FDQ+P5+7293+240706+MDE+BOG++P5+7292+2407042240+2407042339+BOG+MDE'
# UNT+4+1'
# UNZ+1+0001'
#
# ### API Response:
# {'carrier_name': 'Wingo', 'carrier_code': 'P5', 'airplane_model': '737', 'cabin_configuration': 'DEFAULT', 'seat_plan_class': [{'name': 'ECONOMY', 'seat_plan_row': [{'row': 1, 'seat_plan_position': [{'seat_number': '1A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '1D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '1F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 2, 'seat_plan_position': [{'seat_number': '2A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '2D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '2F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 3, 'seat_plan_position': [{'seat_number': '3A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '3D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '3F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 4, 'seat_plan_position': [{'seat_number': '4A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '4D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '4F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 5, 'seat_plan_position': [{'seat_number': '5A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '5D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '5F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 6, 'seat_plan_position': [{'seat_number': '6A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '6D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '6F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 7, 'seat_plan_position': [{'seat_number': '7A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '7D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '7F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 8, 'seat_plan_position': [{'seat_number': '8A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'exit_seat': False, 'type': 'aisle'}, {'seat_number': '8D', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8E', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '8F', 'exit_seat': False, 'type': 'seat'}]}, {'row': 9, 'seat_plan_position': [{'seat_number': '9A', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '9B', 'exit_seat': False, 'type': 'seat'}, {'seat_number': '9C', 'exit_seat': False, 'type': 'seat'}, {'seat_number': 'Ai', 'e ...
# ### Proper Output Edifact Response:
# UNB+IATA:1+ON+W1+240703:1634+0001'
# UNH+1+DCRSMF:03:1:IA'
# FDR+P5+7293+2407062036+MDE+BOG+2407062130'
# RAD+S+O'
# EQD+A:186+++++737'
# CBD+Y+1:34+++++A:W+B:N+C:A+D:A+E:N+F:W'
# ROD+1++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+2++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+3++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+4++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+5++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+6++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+7++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+8++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+9++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+10++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+11++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+12++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+14++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+17++A:F:N:W:E+B:F:N:E+C:F:N:A:E+D:F:N:A:E+E:F:N:E+F:F:N:W:E'
# ROD+18++A:F:N:W:E+B:F:N:E+C:F:N:A:E+D:F:N:A:E+E:F:N:E+F:F:N:W:E'
# ROD+19++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+20++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+21++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+22++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+23++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+24++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+25++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+26++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+27++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+28++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+29++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+30++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+31++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+32++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+33++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# ROD+34++A:F:N:W:I+B:F:N+C:F:N:A+D:F:N:A+E:F:N+F:F:N:W:I'
# UNT+37+1'
# UNZ+1+0001'

# %%
def create_encoding_function(input_edifact_message, api_response, proper_output_edifact_response):
    edifact_encoder_response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
                {"role": "system", "content": SYSTEM_PROMPT},
                {
                    "role": "user",
                    "content": [
                        {
                            "type": "text",
                            "text": (
                                "Please create the encoding function for the following: \n" + 
                                format_examples(structured_examples)
                            ),
                        },
                    ],
                },
            ],
            temperature=0.0,
            response_model=EdifactEncoder,
            max_tokens=4096,
        )
    return edifact_encoder_response

# %%
test_encoding_function = create_encoding_function(
    test_example['edifact_input'],
    test_example['api_response'],
    test_example['edifact_output']
)
print(test_encoding_function)
# Out:
# encoding_function='def encode_edifact(input_message, api_response):\n    def format_date(date_str):\n        return date_str[:6] + \'1300\' if len(date_str) == 6 else date_str\n\n    def format_seat(seat):\n        return f\'{seat["seat_number"]}:{"E" if seat["exit_seat"] else "N"}\'\n\n    def format_row(row):\n        return \'+\'.join([format_seat(seat) for seat in row["seat_plan_position"]])\n\n    def format_class(seat_class):\n        return f\'CBD+Y+1:{len(seat_class["seat_plan_row"])}+++++A:N+B:N+C:N+D:N+E:N+F:N\'\n\n    def format_rod(seat_class):\n        return [f\'ROD+{row["row"]}++{format_row(row)}\' for row in seat_class["seat_plan_row"]]\n\n    segments = input_message.split("\'")\n    output_segments = []\n\n    for segment in segments:\n        if segment.startswith(\'UNB\'):\n            output_segments.append(segment)\n        elif segment.startswith(\'UNH\'):\n            output_segments.append(segment)\n        elif segment.startswith(\'LOR\'):\n            output_segments.append(segment)\n        elif segment.startswith(\'FDQ\'):\n            parts = segment.split(\'+\')\n            parts[4] = format_date(parts[4])\n            output_segments.append(\'+\'.join(parts))\n        elif segment.startswith(\'UNT\'):\n            output_segments.append(segment)\n        elif segment.startswith(\'UNZ\'):\n            output_segments.append(segment)\n\n    if \'error\' in api_response:\n        output_segments.append(f\'ERD+1:5\')\n    else:\n        output_segments.append(f\'FDR+{api_response["carrier_code"]}+{segments[3].split("+")[2]}+{segments[3].split("+")[4]}+{segments[3].split("+")[5]}+{segments[3].split("+")[6]}\')\n        output_segments.append(\'RAD+S+O\')\n        output_segments.append(f\'EQD+Y:{api_response["cabin_configuration"].split()[1]}+++++{api_response["airplane_model"]}\')\n        output_segments.append(format_class(api_response["seat_plan_class"][0]))\n        output_segments.extend(format_rod(api_response["seat_plan_class"][0]))\n\n    output_segments.append(f\'UNT+{len(output_segments) - 1}+1\')\n    output_segments.append(\'UNZ+1+0001\')\n\n    return "\'".join(output_segments) + "\'"\n'

# %%
print(test_encoding_function.encoding_function)
# Out:
# def encode_edifact(input_message, api_response):
#     def format_date(date_str):
#         return date_str[:6] + '1300' if len(date_str) == 6 else date_str
#
#     def format_seat(seat):
#         return f'{seat["seat_number"]}:{"E" if seat["exit_seat"] else "N"}'
#
#     def format_row(row):
#         return '+'.join([format_seat(seat) for seat in row["seat_plan_position"]])
#
#     def format_class(seat_class):
#         return f'CBD+Y+1:{len(seat_class["seat_plan_row"])}+++++A:N+B:N+C:N+D:N+E:N+F:N'
#
#     def format_rod(seat_class):
#         return [f'ROD+{row["row"]}++{format_row(row)}' for row in seat_class["seat_plan_row"]]
#
#     segments = input_message.split("'")
#     output_segments = []
#
#     for segment in segments:
#         if segment.startswith('UNB'):
#             output_segments.append(segment)
#         elif segment.startswith('UNH'):
#             output_segments.append(segment)
#         elif segment.startswith('LOR'):
#             output_segments.append(segment)
#         elif segment.startswith('FDQ'):
#             parts = segment.split('+')
#             parts[4] = format_date(parts[4])
#             output_segments.append('+'.join(parts))
#         elif segment.startswith('UNT'):
#             output_segments.append(segment)
#         elif segment.startswith('UNZ'):
#             output_segments.append(segment)
#
#     if 'error' in api_response:
#         output_segments.append(f'ERD+1:5')
#     else:
#         output_segments.append(f'FDR+{api_response["carrier_code"]}+{segments[3].split("+")[2]}+{segments[3].split("+")[4]}+{segments[3].split("+")[5]}+{segments[3].split("+")[6]}')
#         output_segments.append('RAD+S+O')
#         output_segments.append(f'EQD+Y:{api_response["cabin_configuration"].split()[1]}+++++{api_response["airplane_model"]}')
#         output_segments.append(format_class(api_response["seat_plan_class"][0]))
#         output_segments.extend(format_rod(api_response["seat_plan_class"][0]))
#
#     output_segments.append(f'UNT+{len(output_segments) - 1}+1')
#     output_segments.append('UNZ+1+0001')
#
#     return "'".join(output_segments) + "'"

# %%
def encode_edifact(input_message, api_response):
    def format_date(date_str):
        return date_str[:6] + '1300' if len(date_str) == 6 else date_str

    def format_seat(seat):
        return f'{seat["seat_number"]}:{"E" if seat["exit_seat"] else "N"}'

    def format_row(row):
        return '+'.join([format_seat(seat) for seat in row["seat_plan_position"]])

    def format_class(seat_class):
        return f'CBD+Y+1:{len(seat_class["seat_plan_row"])}+++++A:N+B:N+C:N+D:N+E:N+F:N'

    def format_rod(seat_class):
        return [f'ROD+{row["row"]}++{format_row(row)}' for row in seat_class["seat_plan_row"]]

    segments = input_message.split("'")
    output_segments = []

    for segment in segments:
        if segment.startswith('UNB'):
            output_segments.append(segment)
        elif segment.startswith('UNH'):
            output_segments.append(segment)
        elif segment.startswith('LOR'):
            output_segments.append(segment)
        elif segment.startswith('FDQ'):
            parts = segment.split('+')
            parts[4] = format_date(parts[4])
            output_segments.append('+'.join(parts))
        elif segment.startswith('UNT'):
            output_segments.append(segment)
        elif segment.startswith('UNZ'):
            output_segments.append(segment)

    if 'error' in api_response:
        output_segments.append(f'ERD+1:5')
    else:
        output_segments.append(f'FDR+{api_response["carrier_code"]}+{segments[3].split("+")[2]}+{segments[3].split("+")[4]}+{segments[3].split("+")[5]}+{segments[3].split("+")[6]}')
        output_segments.append('RAD+S+O')
        output_segments.append(f'EQD+Y:{api_response["cabin_configuration"].split()[1]}+++++{api_response["airplane_model"]}')
        output_segments.append(format_class(api_response["seat_plan_class"][0]))
        output_segments.extend(format_rod(api_response["seat_plan_class"][0]))

    output_segments.append(f'UNT+{len(output_segments) - 1}+1')
    output_segments.append('UNZ+1+0001')

    return "'".join(output_segments) + "'"

# %%
for example in structured_examples:
    encoded_output = encode_edifact(example['edifact_input'], example['api_response'])
    expected_output = example['edifact_output']
    
    if encoded_output == expected_output:
        print("Input and output match.")
    else:
        print("Input and output do not match.")
        print("Encoded output:")
        print(encoded_output)
        print("Expected output:")
        print(expected_output)
    
    print("\n\n")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[84], line 2
#       1 for example in structured_examples:
# ----> 2     encoded_output = encode_edifact(example['edifact_input'], example['api_response'])
#       3     expected_output = example['edifact_output']
#       5     if encoded_output == expected_output:
#
# Cell In[83], line 41, in encode_edifact(input_message, api_response)
#      39 output_segments.append(f'FDR+{api_response["carrier_code"]}+{segments[3].split("+")[2]}+{segments[3].split("+")[4]}+{segments[3].split("+")[5]}+{segments[3].split("+")[6]}')
#      40 output_segments.append('RAD+S+O')
# ---> 41 output_segments.append(f'EQD+Y:{api_response["cabin_configuration"].split()[1]}+++++{api_response["airplane_model"]}')
#      42 output_segments.append(format_class(api_response["seat_plan_class"][0]))
#      43 output_segments.extend(format_rod(api_response["seat_plan_class"][0]))
#
# IndexError: list index out of range

# %%
def encode_edifact2(input_message, api_response):
    # Parse the input message
    segments = input_message.strip().split("'\n")
    unb_segment = segments[0]
    unz_segment = segments[-1]
    # Extract relevant data from the API response
    carrier_name = api_response.get('carrier_name', 'Unknown Carrier')
    carrier_code = api_response.get('carrier_code', 'Unknown Code')
    airplane_model = api_response.get('airplane_model', 'Unknown Model')
    cabin_configuration = api_response.get('cabin_configuration', 'Unknown Configuration')
    seat_plan_class = api_response.get('seat_plan_class', [])

    # Prepare the output segments
    output_segments = []
    output_segments.append(unb_segment)
    output_segments.append("UNH+1+DCRSMF:03:1:IA'")

    # Add flight details
    if 'LOR' in segments[1]:
        flight_info = segments[1].split('+')
        output_segments.append(f"FDR+{carrier_code}+{flight_info[1]}+{flight_info[2]}+{flight_info[3]}+{flight_info[4]}+{flight_info[5]}+")
    else:
        output_segments.append(f"FDR+{carrier_code}+{flight_info[1]}+{flight_info[2]}+{flight_info[3]}+")

    output_segments.append("RAD+S+O'")
    output_segments.append(unz_segment)

    # Join all segments into a single output message
    return "'\n".join(output_segments)

# %%
for example in structured_examples:
    encoded_output = encode_edifact2(example['edifact_input'], example['api_response'])
    expected_output = example['edifact_output']
    
    if encoded_output == expected_output:
        print("Input and output match.")
    else:
        print("Input and output do not match.")
        print("Encoded output:")
        print(encoded_output)
        print("Expected output:")
        print(expected_output)
    
    print("\n\n")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[22], line 2
#       1 for example in structured_examples:
# ----> 2     encoded_output = encode_edifact2(example['edifact_input'], example['api_response'])
#       3     expected_output = example['edifact_output']
#       5     if encoded_output == expected_output:
#
# Cell In[21], line 23, in encode_edifact2(input_message, api_response)
#      21     output_segments.append(f"FDR+{carrier_code}+{flight_info[1]}+{flight_info[2]}+{flight_info[3]}+{flight_info[4]}+{flight_info[5]}+")
#      22 else:
# ---> 23     output_segments.append(f"FDR+{carrier_code}+{flight_info[1]}+{flight_info[2]}+{flight_info[3]}+")
#      25 output_segments.append("RAD+S+O'")
#      26 output_segments.append(unz_segment)
#
# UnboundLocalError: cannot access local variable 'flight_info' where it is not associated with a value
